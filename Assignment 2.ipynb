# %% [markdown]
# #### 1. Email Validator (String Filtering + Loops)

# %% [markdown]
# 💼 Real-world use: Used in signup forms or data cleaning tasks.
# Task:
# Check if a given email is valid — must contain “@” and end with “.com” or “.org”.
# Example:
# Input: hello@inceptionbd.com
# Output: Valid Email

# %%
email = input("Enter your email: ")
check =  email.find('@')
if check != -1 and check != 0 and (email.endswith(".com") or email.endswith(".org")):
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Enter your email:  adir@gmail.com
# Valid Email

# %% [markdown]
# #### 2. Count Word Frequency in Customer Reviews

# %% [markdown]
# 💼 Real-world use: Analyzing reviews or comments in text analytics.
# Task:
# Given a review text, count how many times each word appears (ignore case).
# Example:
# Input: "This product is good and this service is excellent"
# Output: {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}

# %%
review = input("Enter your review: ")
review = review.lower()
words = review.split()
word_count = {}
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print(word_count)
# Out:
# Enter your review:  This boy is very good and he is also good in english
# {'this': 1, 'boy': 1, 'is': 2, 'very': 1, 'good': 2, 'and': 1, 'he': 1, 'also': 1, 'in': 1, 'english': 1}

# %% [markdown]
# #### 3. Password Strength Checker

# %% [markdown]
# 💼 Real-world use: Used in user authentication systems.
# Task:
# Check if a password is strong — must have at least one uppercase, one lowercase, one digit, and one
# special character.
# Example:
# Input: "Hello@123"
# Output: Strong Password

# %%
password = input("Enter your password: ")

special = "!@#$%^&*()-_=+[]{};:,<.>/?"

has_upper = any(char.isupper() for char in password)
has_lower = any(char.islower() for char in password)
has_digit = any(char.isdigit() for char in password)
has_special = any(char in special for char in password)

if has_upper and has_lower and has_digit and has_special:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter your password:  Anaiza#7
# Strong Password

# %% [markdown]
# #### 4. Username Generator

# %% [markdown]
# 💼 Real-world use: Automatically create usernames for users.
# Task:
# Take user’s full name and generate a short username.
# Rules: first 3 letters of first name + last 3 letters of last name + random number (use loops only).
# Example:
# Input: "Mamun Malitha"
# Output: mamitha57

# %%
import random

full_name = input("Enter your full name: ")

names = full_name.split()
first = names[0].lower()
last = names[-1].lower()

first_part = ""
count = 0
for ch in first:
    if count < 3:
        first_part += ch
        count += 1

last_part = ""
count = 0
for ch in reversed(last):
    if count < 3:
        last_part = ch + last_part
        count += 1

num = ""
for i in range(2):
    num += str(random.randint(0, 9))

username = first_part + last_part + num

print("Generated Username:", username)
# Out:
# Enter your full name:  Mamun Malitha
# Generated Username: mamtha53

# %% [markdown]
# #### 5. SMS Word Counter

# %% [markdown]
# 💼 Real-world use: Used in messaging apps or social media post limit check.
# Task:
# Count how many characters and words are in a message, and tell if it exceeds 160 characters (SMS limit).
# Example:
# Input: "This is a demo message."
# Output: Words = 5, Characters = 23, Status = Within Limit

# %%
message = input("Enter your message: ")

char_count = len(message)

words = message.split()
word_count = len(words)

if char_count > 160:
    status = "Exceeds Limit"
else:
    status = "Within Limit"

print("Words =", word_count)
print("Characters =", char_count)
print("Status =", status)
# Out:
# Enter your message:  This message is for your count
# Words = 6
# Characters = 30
# Status = Within Limit

# %% [markdown]
# #### 6. Remove Duplicates from Contact List

# %% [markdown]
# 💼 Real-world use: Data cleaning in CRM or user databases.
# Task:
# Given a list of names (comma separated), remove duplicates.
# Example:
# Input: "Rahim, Karim, Rahim, Sultana"
# Output: "Rahim, Karim, Sultana"

# %%
contacts = input("Enter names separated by commas: ")

names = [name.strip() for name in contacts.split(",")]

unique_names = []
for name in names:
    if name not in unique_names:
        unique_names.append(name)

result = ", ".join(unique_names)

print(result)
# Out:
# Enter names separated by commas:  Anaiza, Adira, Adiba, Anaiza, Adira
# Anaiza, Adira, Adiba

# %% [markdown]
# #### 7. Detect Suspicious Words in Text (Moderation)

# %% [markdown]
# 💼 Real-world use: Used in chat moderation or email filtering.
# Task:
# If any “banned” words like ['spam', 'scam', 'fake'] are found in a text, print “Warning”.
# Example:
# Input: "This is a scam offer"
# Output: Warning: Suspicious content detected

# %%
text = input("Enter your text: ").lower()

banned_words = ['spam', 'scam', 'fake']

found = False
for word in banned_words:
    if word in text:
        found = True
        break

if found:
    print("Warning: Suspicious content detected")
else:
    print("Clean: No suspicious content found")
# Out:
# Enter your text:  Where are you going, don't buy any fake ornaments.
# Warning: Suspicious content detected

# %% [markdown]
# #### 8. Invoice Code Formatter

# %% [markdown]
# 💼 Real-world use: Formatting IDs or codes in finance or ERP systems.
# Task:
# Given an invoice number like 23, generate code in the format INV00023.
# Example:
# Input: 23
# Output: INV00023

# %%
number = int(input("Enter invoice number: "))

formatted_number = str(number).zfill(5)

invoice_code = "INV" + formatted_number

print(invoice_code)
# Out:
# Enter invoice number:  678
# INV00678

# %% [markdown]
# #### 9. Count Hashtags and Mentions (Social Media Analytics)

# %% [markdown]
# 💼 Real-world use: Used in analyzing social media posts.
# Task:
# Count how many hashtags (#) and mentions (@) appear in a post.
# Example:
# Input: "Check out #AIWorkshop and follow @inceptionbd"
# Output: Hashtags = 1, Mentions = 1

# %%
post = input("Enter your post: ")

hashtag_count = 0
mention_count = 0

for char in post:
    if char == '#':
        hashtag_count += 1
    elif char == '@':
        mention_count += 1

print("Hashtags =", hashtag_count)
print("Mentions =", mention_count)
# Out:
# Enter your post:  Please join #AIWorkshop and log in name@inceptionbd
# Hashtags = 1
# Mentions = 1

# %% [markdown]
# #### 10. Word Reversal for Data Encryption

# %% [markdown]
# 💼 Real-world use: Simple text obfuscation or playful encoding.
# Task:
# Reverse each word in a sentence while keeping word order the same.
# Example:
# Input: "AI is fun"
# Output: "IA si nuf"

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()

reversed_words = [word[::-1] for word in words]

result = " ".join(reversed_words)

print("Encrypted Output:", result)
# Out:
# Enter a sentence:  numpy
# Encrypted Output: ypmun
